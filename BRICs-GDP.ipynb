# %%
from pandas_datareader import wb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from pandas_datareader import wb

matches = wb.search('GDP [current US$]')

dat = wb.download(indicator='NY.GDP.MKTP.CD', country=['BRA', 'CHN', 'IND', 'ZAF', 'RUS'], start=1960, end=2020)

# %%
pd.set_option('float_format', '{:.0f}'.format)

# %%
data = dat.pivot_table(values='NY.GDP.MKTP.CD', index=['year'], columns=['country'])
data
# Out:
# country        Brazil          China         India  Russian Federation  \
# year
# 1960      15165569913    59716467625   37029883875                 NaN
# 1961      15236854859    50056868958   39232435784                 NaN
# 1962      19926293839    47209359006   42161481859                 NaN
# 1963      23021477292    50706799903   48421923459                 NaN
# 1964      21211892260    59708343489   56480289941                 NaN
# ...               ...            ...           ...                 ...
# 2016    1795700168991 11233276536745 2294797980510       1276786979222
# 2017    2063507864887 12310409370894 2651472946375       1574199387071
# 2018    1916947014068 13894817549380 2701111782775       1657328865710
# 2019    1877810514260 14279937467431 2870504096717       1687448525467
# 2020    1444733258972 14722730697890 2622983732006       1483497784868
#
# country  South Africa
# year
# 1960       7575396973
# 1961       7972996814
# 1962       8497996604
# ...

# %%
data.iplot(kind='line')
# Out:
# <div>                            <div id="88873953-2a41-4c47-b2ed-fe84cfd25b3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
data[['Brazil', 'India']].iplot(kind='barh')
# Out:
# <div>                            <div id="3f6575f4-8139-468e-918d-2cf209cd0df8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
